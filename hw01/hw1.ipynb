# %% [markdown]
# # hw 1

# %% [markdown]
# ## quesiton 1
# ![dsc_logo_vertical.png](attachment:dsc_logo_vertical.png)
# https://www.datasciencecentral.com/

# %% [markdown]
# ## question 2

# %% [markdown]
# > *“The world is one big data problem.”* – by Andrew McAfee, co-director of the MIT Initiative

# %% [markdown]
# ## question 3

# %%
x=[]
y=[]
for i in range (0,1001):
    x.append(i)
for i in x:
    i=3*(i**2)+2*i+4
    y.append(i)
    
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()

# %% [markdown]
# $$f(x) = 3x^2+2x+4$$

# %% [markdown]
# ## question 4

# %% [markdown]
# | Python Packages      | Github Stars |
# | ----------- | ----------- |
# | pandas      | 28k       |
# | TensorFlow   | 152k       |
# | Home Assistant      | 39.2k       |
# | PyTorch   | 45.5k       |
# | Ansible   | 46.6k       |

# %% [markdown]
# ## question 5

# %%
! pwd
# Out:
# /Users/liaonicole/Desktop

# %%
! cd /Users/liaonicole/Desktop/mds

# %%
# %load file1.py
print("The answer is 42.")
# Out:
# The answer is 42.
